# %%
import numpy as np
import pandas as pd
import random as rand

import requests
import json
import re
from json import loads

# %%
bus_station = pd.read_csv('서울시버스정류소좌표데이터(2022.08.24).csv', encoding='euc-kr')

name_lst =['안암_우신향병원']

num = 7
j=1
bus_station_name = ['이문동교회','여의도역','홍대입구역','동천학교','63빌딩.가톨릭대학교여의도성모병원','태릉입구역7번출구.서울생활사박물관','성원아파트경남아너스빌앞']
for i in bus_station_name:
    for i in range(len(bus_station)):
        if bus_station.iloc[i,2] in bus_station_name:
            j+=1
            globals()[f'loc{j}_name'] = bus_station.iloc[j,2]
            globals()[f'loc{j}_X'] = bus_station.iloc[j,3]
            globals()[f'loc{j}_Y'] = bus_station.iloc[j,4]

# %%
# Starting point는 0 부여
loc0_name = '안암_우신향'
loc0_X = '127.0311'
loc0_Y = '37.5851'

# %%
print(loc2_name, loc2_X, loc2_Y)
# Out:
# 명륜3가.성대입구 126.9982901625 37.5827088189

# %%
url = "https://apis.openapi.sk.com/tmap/matrix?version=1"

payload = {
    "origins": [
        {
            "lon": str(globals()[f'loc{i}_X']),
            "lat": str(globals()[f'loc{i}_Y']),
        } for i in range(num)
    ],
    "destinations": [
        {
            "lon": str(globals()[f'loc{i}_X']),
            "lat": str(globals()[f'loc{i}_Y']),
        } for i in range(num)
    ],
    "transportMode": "car",
    "metric": "Recommendation"
}
headers = {
    "Accept": "application/json",
    "appKey": "l7xxcdd1a30a6b34450a881f8083994a8cd4",
    "Content-Type": "application/json"
}

response = requests.post(url, json=payload, headers=headers)

# %%
jsonObj = json.loads(response.text)
jsonObj
# Out:
# {'meta': {'status': 'Ok',
#   'message': 'Ok',
#   'moduleVersion': '',
#   'mapVersion': '20221018',
#   'elapsedTime': 0,
#   'realTimeTrafficDateTime': '',
#   'patternTrafficDate': '',
#   'customizationDateTime': '',
#   'algorithm': '',
#   'metric': 'Recommendation',
#   'requestId': 'ef3d848b-b521-4020-b221-e34f2d9e302b',
#   'gasStationPriceDateTime': '',
#   'transportMode': 'Car',
#   'avoid': []},
#  'origins': [{'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5851, 'longitude': 127.0311},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5791788583, 'longitude': 126.9965201597},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5827088189, 'longitude': 126.9982901625},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5685822333, 'longitude': 126.9875072018},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5862299819, 'longitude': 127.0016943494},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5662075233, 'longitude': 126.966960795},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.569098089, 'longitude': 126.9704199006},
#    'rpFlag': ''}],
#  'destinations': [{'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5851, 'longitude': 127.0311},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5791788583, 'longitude': 126.9965201597},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5827088189, 'longitude': 126.9982901625},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5685822333, 'longitude': 126.9875072018},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5862299819, 'longitude': 127.0016943494},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5662075233, 'longitude': 126.966960795},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.569098089, 'longitude': 126.9704199006},
#    'rpFlag': ''}],
#  'matrixRoutes': [{'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 907,
#    'distance': 4969.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 849,
#    'distance': 4516.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 1003,
#    'distance': 4789.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 755,
#    'distance': 4022.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 1225,
#    'distance': 6624.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 1348,
#    'distance': 7113.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 1072,
#    'distance': 4973.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 372,
#    'distance': 1519.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 521,
#    'distance': 1985.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 754,
#    'distance': 3080.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 743,
#    'distance': 3819.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 843,
#    'distance': 4327.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 1131,
#    'distance': 5425.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 59,
#    'distance': 452.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 580,
#    'distance': 2437.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 812,
#    'distance': 3533.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 802,
#    'distance': 4272.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 902,
#    'distance': 4780.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 1254,
#    'distance': 5728.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 651,
#    'distance': 3435.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 705,
#    'distance': 3790.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 1086,
#    'distance': 5350.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 475,
#    'distance': 2167.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 471,
#    'distance': 2259.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 1025,
#    'distance': 3535.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 153,
#    'distance': 946.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 94,
#    'distance': 494.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 674,
#    'distance': 2931.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 896,
#    'distance': 4766.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 996,
#    'distance': 5274.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 1872,
#    'distance': 7511.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 1048,
#    'distance': 5286.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 1102,
#    'distance': 5641.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 868,
#    'distance': 2759.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 1483,
#    'distance': 7202.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 362,
#    'distance': 1028.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 1510,
#    'distance': 6482.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 930,
#    'distance': 4162.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 984,
#    'distance': 4517.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 506,
#    'distance': 1730.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 1365,
#    'distance': 6077.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 228,
#    'distance': 1021.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False}]}

# %%
duration_lst = []
for i in range(num**2):
    duration_lst.append(jsonObj['matrixRoutes'][i]['duration'])
duration = np.array(duration_lst).reshape(num,num)

# %%
np.save('고연전_MVP_테스트_경로매트릭스(분)',duration)
