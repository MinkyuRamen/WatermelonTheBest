# %%
import numpy as np
import pandas as pd
import random as rand

import requests
import json
import re
from json import loads

# %%
bus_station = pd.read_csv('서울시버스정류소좌표데이터(2022.08.24).csv', encoding='euc-kr')
bus_station = bus_station.sample(n=100)
bus_station
# Out:
#          NODE_ID  ARS-ID         정류소명         좌표X        좌표Y
# 1507   104000112    5205       건국대학교앞  127.074928  37.538577
# 1247   103000279    4722         무학여고  127.034051  37.558285
# 4592   111000335   12430   진관중고교.약수사앞  126.923140  37.643400
# 923    102000274    3732  이촌동두산위브트레지움  126.966001  37.521546
# 3956   110000184   11284      석계역2번출구  127.067004  37.615194
# ...          ...     ...          ...         ...        ...
# 1073   103000130    4231         사근고개  127.044515  37.561232
# 10466  123000584   24233      한성백제박물관  127.119327  37.515347
# 1093   103900213    4256        성수사거리  127.062464  37.542522
# 5186   112900118   13855         민속식당  126.929665  37.567986
# 1622   104900116    5572        행운슈퍼앞  127.086998  37.532971
#
# [100 rows x 5 columns]

# %%
# Starting point는 0 부여
loc0_name = '강남역'
loc0_X = '127.028361548'
loc0_Y = '37.496486063'

# %%
# 목적지는 1부터 네이밍;; 목적지 개수는 (num-1) 개

num = 20 # 총 노드 개수

for i in range(1,num): # 1~(n-1)
    globals()[f'loc{i}_name'] = bus_station.iloc[i,2]
    globals()[f'loc{i}_X'] = bus_station.iloc[i,3]
    globals()[f'loc{i}_Y'] = bus_station.iloc[i,4]

# %%
print(loc1_name, loc1_X, loc1_Y)
# Out:
# 무학여고 127.0340505738 37.5582850004

# %%
url = "https://apis.openapi.sk.com/tmap/matrix?version=1"

payload = {
    "origins": [
        {
            "lon": str(globals()[f'loc{i}_X']),
            "lat": str(globals()[f'loc{i}_Y']),
        } for i in range(num)
    ],
    "destinations": [
        {
            "lon": str(globals()[f'loc{i}_X']),
            "lat": str(globals()[f'loc{i}_Y']),
        } for i in range(num)
    ],
    "transportMode": "car",
    "metric": "Recommendation"
}
headers = {
    "Accept": "application/json",
    "appKey": "l7xx4d23b06a733d4f2e9c5365ca49c3431a",
    "Content-Type": "application/json"
}

response = requests.post(url, json=payload, headers=headers)

# %%
jsonObj = json.loads(response.text)
jsonObj
# Out:
# {'meta': {'status': 'Ok',
#   'message': 'Ok',
#   'moduleVersion': '',
#   'mapVersion': '20220920',
#   'elapsedTime': 0,
#   'realTimeTrafficDateTime': '',
#   'patternTrafficDate': '',
#   'customizationDateTime': '',
#   'algorithm': '',
#   'metric': 'Recommendation',
#   'requestId': '1c0aa0a9-1cd1-43be-b42b-03f1c36a5fd5',
#   'gasStationPriceDateTime': '',
#   'transportMode': 'Car',
#   'avoid': []},
#  'origins': [{'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.496486063, 'longitude': 127.028361548},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5582850004, 'longitude': 127.0340505738},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.6434001879, 'longitude': 126.9231400464},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.521546034, 'longitude': 126.9660012496},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.6151943546, 'longitude': 127.0670040201},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.6338530073, 'longitude': 127.077825958},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5749465941, 'longitude': 126.9680704944},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.6140827146, 'longitude': 126.917821606},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.6027418064, 'longitude': 126.9225884696},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.4692806245, 'longitude': 126.9314987334},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5577937282, 'longitude': 127.0399242207},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5372888336, 'longitude': 126.894948559},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5828993652, 'longitude': 127.0538976376},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.6237909963, 'longitude': 127.0865569082},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.585841, 'longitude': 127.001025},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5565612291, 'longitude': 126.9232572961},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.6062995297, 'longitude': 127.0149146547},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5444258914, 'longitude': 126.9531309736},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5490286106, 'longitude': 127.1300386813},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5603875036, 'longitude': 126.8565633389},
#    'rpFlag': ''}],
#  'destinations': [{'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.496486063, 'longitude': 127.028361548},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5582850004, 'longitude': 127.0340505738},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.6434001879, 'longitude': 126.9231400464},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.521546034, 'longitude': 126.9660012496},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.6151943546, 'longitude': 127.0670040201},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.6338530073, 'longitude': 127.077825958},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5749465941, 'longitude': 126.9680704944},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.6140827146, 'longitude': 126.917821606},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.6027418064, 'longitude': 126.9225884696},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.4692806245, 'longitude': 126.9314987334},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5577937282, 'longitude': 127.0399242207},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5372888336, 'longitude': 126.894948559},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5828993652, 'longitude': 127.0538976376},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.6237909963, 'longitude': 127.0865569082},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.585841, 'longitude': 127.001025},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5565612291, 'longitude': 126.9232572961},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.6062995297, 'longitude': 127.0149146547},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5444258914, 'longitude': 126.9531309736},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5490286106, 'longitude': 127.1300386813},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5603875036, 'longitude': 126.8565633389},
#    'rpFlag': ''}],
#  'matrixRoutes': [{'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 1913,
#    'distance': 8005.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 5010,
#    'distance': 39835.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 1793,
#    'distance': 8722.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 3043,
#    'distance': 18907.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 3432,
#    'distance': 22716.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 2923,
#    'distance': 11466.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 4331,
#    'distance': 18425.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 4229,
#    'distance': 17427.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 2383,
#    'distance': 11674.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 2051,
#    'distance': 8622.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 2694,
#    'distance': 16106.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 2735,
#    'distance': 13321.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 3459,
#    'distance': 20051.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 2147,
#    'distance': 11127.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 3042,
#    'distance': 15750.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 3613,
#    'distance': 18386.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 2577,
#    'distance': 13833.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 2304,
#    'distance': 12212.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 3603,
#    'distance': 21316.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 2259,
#    'distance': 8686.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 3767,
#    'distance': 21927.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 1899,
#    'distance': 9440.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 1728,
#    'distance': 13301.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 2117,
#    'distance': 17110.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 2756,
#    'distance': 7521.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 3679,
#    'distance': 19413.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 3577,
#    'distance': 18415.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 3927,
#    'distance': 22385.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 138,
#    'distance': 617.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 3214,
#    'distance': 18319.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 825,
#    'distance': 4101.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 2144,
#    'distance': 14445.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 1396,
#    'distance': 5573.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 3148,
#    'distance': 16467.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 1858,
#    'distance': 7244.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 2683,
#    'distance': 14551.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 2121,
#    'distance': 14318.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 3708,
#    'distance': 22033.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 4734,
#    'distance': 22996.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 3390,
#    'distance': 23383.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 3489,
#    'distance': 16349.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 3070,
#    'distance': 28105.8,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 3041,
#    'distance': 29080.4,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 2169,
#    'distance': 10519.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 1250,
#    'distance': 4646.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 1516,
#    'distance': 6104.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 4520,
#    'distance': 34888.9,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 3318,
#    'distance': 22573.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 3051,
#    'distance': 14982.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 3521,
#    'distance': 19713.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 2836,
#    'distance': 30958.6,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 3322,
#    'distance': 14616.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 2567,
#    'distance': 11637.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 2923,
#    'distance': 14797.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 2923,
#    'distance': 13981.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 4306,
#    'distance': 44744.5,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 3214,
#    'distance': 29093.9,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 2060,
#    'distance': 9740.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 1637,
#    'distance': 9441.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 3439,
#    'distance': 31341.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 2937,
#    'distance': 20321.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 3327,
#    'distance': 24129.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 1638,
#    'distance': 7708.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 2984,
#    'distance': 15445.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 2390,
#    'distance': 12787.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 2311,
#    'distance': 8580.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 1775,
#    'distance': 10059.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 1265,
#    'distance': 8779.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 2630,
#    'distance': 14735.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 3353,
#    'distance': 21465.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 2413,
#    'distance': 12275.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 1471,
#    'distance': 7256.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 3508,
#    'distance': 19800.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 1005,
#    'distance': 5339.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 2894,
#    'distance': 20368.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 1903,
#    'distance': 12619.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 3493,
#    'distance': 19122.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 1998,
#    'distance': 13695.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 3774,
#    'distance': 34025.8,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 3311,
#    'distance': 18991.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 776,
#    'distance': 3182.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 3715,
#    'distance': 16243.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 3807,
#    'distance': 16298.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 3706,
#    'distance': 15300.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 5160,
#    'distance': 32821.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 1596,
#    'distance': 8798.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 3646,
#    'distance': 22784.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 1515,
#    'distance': 5480.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 658,
#    'distance': 2269.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 1842,
#    'distance': 7497.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 3380,
#    'distance': 18712.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 1406,
#    'distance': 5565.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 4094,
#    'distance': 24101.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 2406,
#    'distance': 17138.5,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 3862,
#    'distance': 23876.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 4035,
#    'distance': 21702.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 2541,
#    'distance': 16274.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 3737,
#    'distance': 33545.8,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 3853,
#    'distance': 21570.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 661,
#    'distance': 3110.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 4246,
#    'distance': 20245.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 4339,
#    'distance': 20300.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 4237,
#    'distance': 19302.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 5471,
#    'distance': 39003.3,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 2415,
#    'distance': 12816.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 4178,
#    'distance': 26786.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 2058,
#    'distance': 8059.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 332,
#    'distance': 1779.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 2284,
#    'distance': 10357.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 3911,
#    'distance': 22714.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 2225,
#    'distance': 9584.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 4637,
#    'distance': 26681.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 2449,
#    'distance': 17241.5,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 4394,
#    'distance': 27878.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 3078,
#    'distance': 11798.3,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 2232,
#    'distance': 8753.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 2311,
#    'distance': 10987.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 1523,
#    'distance': 7448.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 2363,
#    'distance': 17983.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 2897,
#    'distance': 20040.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 1490,
#    'distance': 7130.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 1388,
#    'distance': 6132.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 3403,
#    'distance': 15243.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 2160,
#    'distance': 7942.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 2015,
#    'distance': 9318.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 2383,
#    'distance': 8635.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 2779,
#    'distance': 19127.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 1153,
#    'distance': 4097.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 1142,
#    'distance': 5445.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 2068,
#    'distance': 10823.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 957,
#    'distance': 5081.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 4183,
#    'distance': 21417.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 2509,
#    'distance': 13032.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 4132,
#    'distance': 26236.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 2520,
#    'distance': 19148.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 1042,
#    'distance': 4558.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 2980,
#    'distance': 16076.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 2348,
#    'distance': 17721.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 2882,
#    'distance': 19778.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 1412,
#    'distance': 7206.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 452,
#    'distance': 2088.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 3456,
#    'distance': 30873.0,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 2448,
#    'distance': 18337.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 1987,
#    'distance': 10966.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 2651,
#    'distance': 15477.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 2764,
#    'distance': 18865.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 2359,
#    'distance': 12432.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 1503,
#    'distance': 7622.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 2053,
#    'distance': 10561.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 2166,
#    'distance': 10669.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 3885,
#    'distance': 33855.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 2180,
#    'distance': 11269.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 4018,
#    'distance': 25388.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 2475,
#    'distance': 19037.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 1459,
#    'distance': 6024.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 2574,
#    'distance': 12003.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 2303,
#    'distance': 17610.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 2837,
#    'distance': 19667.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 1255,
#    'distance': 6172.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 418,
#    'distance': 1466.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 3342,
#    'distance': 30025.6,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 2403,
#    'distance': 18226.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 1873,
#    'distance': 10119.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 2607,
#    'distance': 15366.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 2719,
#    'distance': 18754.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 2407,
#    'distance': 10270.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 1134,
#    'distance': 6282.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 2008,
#    'distance': 10450.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 2008,
#    'distance': 9635.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 3840,
#    'distance': 33744.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 2066,
#    'distance': 10422.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 9,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 2319,
#    'distance': 12435.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 9,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 3094,
#    'distance': 17783.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 9,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 5506,
#    'distance': 45991.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 9,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 1775,
#    'distance': 9060.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 9,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 4394,
#    'distance': 28663.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 9,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 4783,
#    'distance': 32471.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 9,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 3174,
#    'distance': 16084.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 9,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 4638,
#    'distance': 29838.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 9,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 4611,
#    'distance': 30024.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 9,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 9,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 3232,
#    'distance': 18401.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 9,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 3134,
#    'distance': 20824.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 9,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 4087,
#    'distance': 23077.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 9,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 4810,
#    'distance': 29807.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 9,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 3869,
#    'distance': 20617.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 9,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 3027,
#    'distance': 15836.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 9,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 5309,
#    'distance': 36316.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 9,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 2562,
#    'distance': 13920.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 9,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 3987,
#    'distance': 28281.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 9,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 3625,
#    'distance': 24698.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 10,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 2292,
#    'distance': 9202.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 10,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 304,
#    'distance': 1605.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 10,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 4011,
#    'distance': 26334.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 10,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 1848,
#    'distance': 9958.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 10,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 1760,
#    'distance': 13816.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 10,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 2149,
#    'distance': 17625.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 10,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 2815,
#    'distance': 7801.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 10,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 3924,
#    'distance': 23819.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 10,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 3822,
#    'distance': 22821.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 10,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 3960,
#    'distance': 22901.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 10,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 10,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 3163,
#    'distance': 18837.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 10,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 995,
#    'distance': 3780.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 10,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 2176,
#    'distance': 14961.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 10,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 1455,
#    'distance': 5853.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 10,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 3096,
#    'distance': 16985.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 10,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 2060,
#    'distance': 7528.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 10,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 2631,
#    'distance': 15068.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 10,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 1893,
#    'distance': 14046.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 10,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 3657,
#    'distance': 22551.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 11,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 2262,
#    'distance': 15572.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 11,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 2948,
#    'distance': 18709.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 11,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 3023,
#    'distance': 27098.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 11,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 1259,
#    'distance': 8360.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 11,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 3290,
#    'distance': 24979.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 11,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 3824,
#    'distance': 27036.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 11,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 1530,
#    'distance': 8934.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 11,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 2182,
#    'distance': 10973.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 11,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 1918,
#    'distance': 9920.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 11,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 2307,
#    'distance': 24501.2,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 11,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 3086,
#    'distance': 19327.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 11,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 11,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 3593,
#    'distance': 22735.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 11,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 3706,
#    'distance': 26123.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 11,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 2683,
#    'distance': 13032.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 11,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 1032,
#    'distance': 4423.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 11,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 2995,
#    'distance': 17819.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 11,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 1623,
#    'distance': 8145.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 11,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 3793,
#    'distance': 26638.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 11,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 1124,
#    'distance': 5564.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 12,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 2918,
#    'distance': 14528.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 12,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 996,
#    'distance': 5041.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 12,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 3882,
#    'distance': 18900.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 12,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 3166,
#    'distance': 13458.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 12,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 1045,
#    'distance': 4810.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 12,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 1821,
#    'distance': 7993.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 12,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 3275,
#    'distance': 9148.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 12,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 3794,
#    'distance': 16385.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 12,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 3693,
#    'distance': 15387.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 12,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 4921,
#    'distance': 29932.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 12,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 909,
#    'distance': 3663.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 12,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 3633,
#    'distance': 22871.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 12,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 12,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 1703,
#    'distance': 7079.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 12,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 1292,
#    'distance': 5472.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 12,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 3367,
#    'distance': 18799.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 12,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 1393,
#    'distance': 5653.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 12,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 3797,
#    'distance': 11624.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 12,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 2277,
#    'distance': 11033.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 12,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 3849,
#    'distance': 23964.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 13,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 4075,
#    'distance': 24759.0,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 13,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 2832,
#    'distance': 16123.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 13,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 3777,
#    'distance': 34205.2,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 13,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 4144,
#    'distance': 21419.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 13,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 761,
#    'distance': 2179.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 13,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 223,
#    'distance': 1825.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 13,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 4202,
#    'distance': 19216.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 13,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 4295,
#    'distance': 19271.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 13,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 4193,
#    'distance': 18273.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 13,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 5139,
#    'distance': 37224.2,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 13,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 2370,
#    'distance': 11788.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 13,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 4133,
#    'distance': 25757.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 13,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 1774,
#    'distance': 7425.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 13,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 13,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 2616,
#    'distance': 10487.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 13,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 3867,
#    'distance': 21685.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 13,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 2180,
#    'distance': 8555.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 13,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 4796,
#    'distance': 29951.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 13,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 2118,
#    'distance': 15462.4,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 13,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 4349,
#    'distance': 26850.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 14,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 2992,
#    'distance': 13244.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 14,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 1746,
# ...
#    'duration': 5033,
#    'distance': 18475.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 14,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 1674,
#    'distance': 6826.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 14,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 4158,
#    'distance': 14234.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 14,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 1897,
#    'distance': 7519.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 14,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 2856,
#    'distance': 12253.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 14,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 14,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 3284,
#    'distance': 10361.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 14,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 1711,
#    'distance': 6007.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 14,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 2788,
#    'distance': 8543.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 14,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 3677,
#    'distance': 27009.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 14,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 4320,
#    'distance': 22740.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 15,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 2569,
#    'distance': 18236.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 15,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 3189,
#    'distance': 17121.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 15,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 2827,
#    'distance': 26419.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 15,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 1870,
#    'distance': 8398.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 15,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 2966,
#    'distance': 20856.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 15,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 3499,
#    'distance': 22913.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 15,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 1156,
#    'distance': 7638.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 15,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 1663,
#    'distance': 8123.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 15,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 1322,
#    'distance': 7170.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 15,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 2550,
#    'distance': 26524.2,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 15,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 3065,
#    'distance': 21472.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 15,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 874,
#    'distance': 3873.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 15,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 3269,
#    'distance': 18612.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 15,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 3382,
#    'distance': 22000.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 15,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 2308,
#    'distance': 11736.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 15,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 15,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 2671,
#    'distance': 13696.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 15,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 1446,
#    'distance': 5999.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 15,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 4101,
#    'distance': 29302.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 15,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 1368,
#    'distance': 7587.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 16,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 3441,
#    'distance': 18684.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 16,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 1449,
#    'distance': 9226.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 16,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 2949,
#    'distance': 13840.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 16,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 3259,
#    'distance': 18552.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 16,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 1332,
#    'distance': 5813.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 16,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 1768,
#    'distance': 8641.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 16,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 2783,
#    'distance': 7745.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 16,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 2861,
#    'distance': 11326.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 16,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 2759,
#    'distance': 10328.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 16,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 4369,
#    'distance': 37252.5,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 16,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 1377,
#    'distance': 8416.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 16,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 2700,
#    'distance': 17812.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 16,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 1213,
#    'distance': 5576.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 16,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 1993,
#    'distance': 9178.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 16,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 680,
#    'distance': 3306.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 16,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 2433,
#    'distance': 13740.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 16,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 16,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 3362,
#    'distance': 22006.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 16,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 2814,
#    'distance': 23933.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 16,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 2916,
#    'distance': 18904.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 17,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 2802,
#    'distance': 13902.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 17,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 2379,
#    'distance': 13604.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 17,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 3271,
#    'distance': 29515.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 17,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 1060,
#    'distance': 4881.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 17,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 3538,
#    'distance': 27396.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 17,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 4071,
#    'distance': 29453.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 17,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 1099,
#    'distance': 4593.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 17,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 2488,
#    'distance': 10219.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 17,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 1874,
#    'distance': 9011.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 17,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 3008,
#    'distance': 12646.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 17,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 2294,
#    'distance': 9482.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 17,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 1369,
#    'distance': 7281.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 17,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 2570,
#    'distance': 11803.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 17,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 3954,
#    'distance': 28540.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 17,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 1909,
#    'distance': 8092.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 17,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 955,
#    'distance': 3480.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 17,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 3242,
#    'distance': 20236.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 17,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 17,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 3636,
#    'distance': 24530.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 17,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 1863,
#    'distance': 10996.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 18,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 2791,
#    'distance': 14055.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 18,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 1641,
#    'distance': 14543.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 18,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 4792,
#    'distance': 47041.2,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 18,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 3185,
#    'distance': 20384.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 18,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 2233,
#    'distance': 14390.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 18,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 1851,
#    'distance': 17676.4,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 18,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 4218,
#    'distance': 22906.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 18,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 4977,
#    'distance': 34657.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 18,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 4875,
#    'distance': 33659.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 18,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 4431,
#    'distance': 27311.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 18,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 1779,
#    'distance': 15161.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 18,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 4500,
#    'distance': 29263.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 18,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 1907,
#    'distance': 11723.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 18,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 1653,
#    'distance': 15939.7,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 18,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 2556,
#    'distance': 15403.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 18,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 4434,
#    'distance': 27412.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 18,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 2954,
#    'distance': 22902.1,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 18,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 3968,
#    'distance': 25495.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 18,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 18,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 4994,
#    'distance': 32978.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 19,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 2969,
#    'distance': 20527.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 19,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 3414,
#    'distance': 23607.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 19,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 2378,
#    'distance': 22102.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 19,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 1536,
#    'distance': 13323.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 19,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 3338,
#    'distance': 25799.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 19,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 3872,
#    'distance': 27856.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 19,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 1987,
#    'distance': 13074.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 19,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 1860,
#    'distance': 10709.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 19,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 1627,
#    'distance': 10063.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 19,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 2568,
#    'distance': 25465.0,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 19,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 3552,
#    'distance': 24225.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 19,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 816,
#    'distance': 7602.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 19,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 3642,
#    'distance': 23555.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 19,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 3754,
#    'distance': 26943.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 19,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 3139,
#    'distance': 17171.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 19,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 1496,
#    'distance': 10474.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 19,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 3043,
#    'distance': 18640.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 19,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 2025,
#    'distance': 14058.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 19,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 4259,
#    'distance': 31536.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 19,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False}]}

# %%
jsonObj['matrixRoutes'][0]
# Out:
# {'status': 'Ok',
#  'originIndex': 0,
#  'destinationIndex': 0,
#  'cost': 0,
#  'duration': 0,
#  'distance': 0.0,
#  'toll': False}

# %%
duration_lst = []
distance_lst = []
for i in range(num**2):
    duration_lst.append(jsonObj['matrixRoutes'][i]['duration'])
    distance_lst.append(jsonObj['matrixRoutes'][i]['distance'])
duration = np.array(duration_lst).reshape(num,num)
distance = np.array(distance_lst).reshape(num,num)

# %%
print(duration.shape)
duration
# Out:
# (20, 20)
# array([[   0, 1913, 5010, 1793, 3043, 3432, 2923, 4331, 4229, 2383, 2051,
#         2694, 2735, 3459, 2147, 3042, 3613, 2577, 2304, 3603],
#        [2259,    0, 3767, 1899, 1728, 2117, 2756, 3679, 3577, 3927,  138,
#         3214,  825, 2144, 1396, 3148, 1858, 2683, 2121, 3708],
#        [4734, 3390,    0, 3489, 3070, 3041, 2169, 1250, 1516, 4520, 3318,
#         3051, 3521, 2836, 3322, 2567, 2923, 2923, 4306, 3214],
#        [2060, 1637, 3439,    0, 2937, 3327, 1638, 2984, 2390, 2311, 1775,
#         1265, 2630, 3353, 2413, 1471, 3508, 1005, 2894, 1903],
#        [3493, 1998, 3774, 3311,    0,  776, 3715, 3807, 3706, 5160, 1596,
#         3646, 1515,  658, 1842, 3380, 1406, 4094, 2406, 3862],
#        [4035, 2541, 3737, 3853,  661,    0, 4246, 4339, 4237, 5471, 2415,
#         4178, 2058,  332, 2284, 3911, 2225, 4637, 2449, 4394],
#        [3078, 2232, 2311, 1523, 2363, 2897,    0, 1490, 1388, 3403, 2160,
#         2015, 2383, 2779, 1153, 1142, 2068,  957, 4183, 2509],
#        [4132, 2520, 1042, 2980, 2348, 2882, 1412,    0,  452, 3456, 2448,
#         1987, 2651, 2764, 2359, 1503, 2053, 2166, 3885, 2180],
#        [4018, 2475, 1459, 2574, 2303, 2837, 1255,  418,    0, 3342, 2403,
#         1873, 2607, 2719, 2407, 1134, 2008, 2008, 3840, 2066],
#        [2319, 3094, 5506, 1775, 4394, 4783, 3174, 4638, 4611,    0, 3232,
#         3134, 4087, 4810, 3869, 3027, 5309, 2562, 3987, 3625],
#        [2292,  304, 4011, 1848, 1760, 2149, 2815, 3924, 3822, 3960,    0,
#         3163,  995, 2176, 1455, 3096, 2060, 2631, 1893, 3657],
#        [2262, 2948, 3023, 1259, 3290, 3824, 1530, 2182, 1918, 2307, 3086,
#            0, 3593, 3706, 2683, 1032, 2995, 1623, 3793, 1124],
#        [2918,  996, 3882, 3166, 1045, 1821, 3275, 3794, 3693, 4921,  909,
#         3633,    0, 1703, 1292, 3367, 1393, 3797, 2277, 3849],
#        [4075, 2832, 3777, 4144,  761,  223, 4202, 4295, 4193, 5139, 2370,
#         4133, 1774,    0, 2616, 3867, 2180, 4796, 2118, 4349],
#        [2992, 1746, 3327, 3153, 2195, 2631, 2344, 3633, 3531, 5033, 1674,
#         4158, 1897, 2856,    0, 3284, 1711, 2788, 3677, 4320],
#        [2569, 3189, 2827, 1870, 2966, 3499, 1156, 1663, 1322, 2550, 3065,
#          874, 3269, 3382, 2308,    0, 2671, 1446, 4101, 1368],
#        [3441, 1449, 2949, 3259, 1332, 1768, 2783, 2861, 2759, 4369, 1377,
#         2700, 1213, 1993,  680, 2433,    0, 3362, 2814, 2916],
#        [2802, 2379, 3271, 1060, 3538, 4071, 1099, 2488, 1874, 3008, 2294,
#         1369, 2570, 3954, 1909,  955, 3242,    0, 3636, 1863],
#        [2791, 1641, 4792, 3185, 2233, 1851, 4218, 4977, 4875, 4431, 1779,
#         4500, 1907, 1653, 2556, 4434, 2954, 3968,    0, 4994],
#        [2969, 3414, 2378, 1536, 3338, 3872, 1987, 1860, 1627, 2568, 3552,
#          816, 3642, 3754, 3139, 1496, 3043, 2025, 4259,    0]])

# %%
def distance_matrix():
    response = requests.post(url, json=payload, headers=headers)
    jsonObj = json.loads(response.text)

    duration_lst = []
    distance_lst = []
    for i in range(num**2):
        duration_lst.append(jsonObj['matrixRoutes'][i]['duration'])
        distance_lst.append(jsonObj['matrixRoutes'][i]['distance'])
    
    duration = np.array(duration_lst).reshape(num,num)
    distance = np.array(distance_lst).reshape(num,num)

    return duration

distance_matrix()
# Out:
# array([[   0, 1986, 5128, 1826, 3046, 3611, 3020, 4426, 4130, 2618, 2105,
#         3288, 2611, 3345, 2137, 3294, 3530, 2891, 2463, 4081],
#        [1950,    0, 3863, 1703, 1561, 2126, 2985, 3215, 3532, 3939,  157,
#         3410,  840, 1860, 1463, 3171, 1953, 2768, 1973, 4014],
#        [5102, 3855,    0, 3855, 3202, 3369, 2437, 1432, 1835, 5088, 3794,
#         3219, 3827, 2873, 3464, 2709, 3415, 3088, 4245, 2774],
#        [1968, 1849, 3450,    0, 2910, 3475, 1708, 3019, 2941, 2539, 1968,
#         1548, 2474, 3209, 2322, 1616, 3394, 1213, 2953, 2153],
#        [2954, 1735, 3910, 2854,    0,  811, 3865, 3417, 3734, 5089, 1854,
#         3876, 1321,  545, 1826, 3785, 1459, 3919, 2375, 4423],
#        [3547, 2328, 3574, 3447,  610,    0, 4140, 3692, 4009, 5682, 2447,
#         4151, 1914,  400, 2446, 4060, 2027, 4511, 2694, 4699],
#        [2480, 1982, 2218, 1314, 2261, 2825,    0, 1468, 1172, 3371, 2110,
#         1976, 2173, 2560, 1027, 1108, 2061,  843, 3741, 2414],
#        [4084, 2919,  987, 2782, 2679, 3244, 1501,    0,  597, 3850, 2858,
#         2145, 2891, 2978, 2338, 1586, 2479, 2152, 4198, 1976],
#        [3623, 2561, 1326, 2561, 2321, 2886, 1143,  339,    0, 3843, 2500,
#         1925, 2533, 2620, 2170, 1390, 2121, 1794, 3840, 1969],
#        [2304, 3151, 5419, 1673, 4212, 4777, 2963, 4762, 4734,    0, 3270,
#         3130, 3776, 4511, 3624, 3021, 5390, 2438, 3670, 3591],
#        [2145,  330, 4022, 1751, 1723, 2288, 3037, 3374, 3691, 4449,    0,
#         3458,  865, 2022, 1515, 3219, 2112, 3097, 1967, 4063],
#        [2314, 2940, 2739, 1628, 2995, 3560, 1493, 2166, 2139, 2438, 3059,
#            0, 3207, 3294, 2520, 1008, 2795, 1776, 3829,  949],
#        [2828, 1012, 4149, 2977,  974, 1785, 3016, 3500, 3817, 5212,  939,
#         3959,    0, 1519, 1469, 3868, 1619, 3832, 2404, 4507],
#        [3625, 2405, 3660, 3524,  618,  297, 4148, 3699, 4016, 6152, 2525,
#         4159, 1992,    0, 2402, 4068, 2035, 4589, 2294, 4706],
#        [2596, 2021, 3352, 2650, 2215, 2721, 2378, 2704, 3352, 5312, 1960,
#         3754, 1997, 2455,    0, 3199, 1276, 2925, 3664, 4122],
#        [2807, 3223, 2804, 1745, 2871, 3436, 1090, 1691, 1274, 2854, 3050,
#          868, 3083, 3170, 2116,    0, 2671, 1411, 4327, 1366],
#        [3270, 1514, 2911, 3169, 1351, 2141, 2710, 2262, 2579, 4798, 1453,
#         2721, 1206, 1875,  684, 2630,    0, 3381, 2793, 3269],
#        [2644, 2525, 3231, 1047, 3578, 4143, 1072, 2421, 2125, 3044, 2644,
#         1078, 2900, 3877, 2099,  850, 3378,    0, 3629, 1692],
#        [2322, 1659, 4797, 2720, 2262, 1983, 4231, 4401, 4718, 4520, 1739,
#         4182, 1868, 1721, 2697, 4188, 3135, 3785,    0, 4679],
#        [2661, 3287, 2162, 1689, 3269, 3834, 1767, 1998, 1929, 2946, 3406,
#          921, 3481, 3568, 2794, 1506, 3069, 1839, 4175,    0]])
