# %%
import numpy as np
import pandas as pd
import random as rand

import requests
import json
import re
from json import loads

# %%
bus_station = pd.read_csv('서울시버스정류소좌표데이터(2022.08.24).csv', encoding='euc-kr')
bus_station = bus_station.sample(n=100)
bus_station
# Out:
#          NODE_ID  ARS-ID               정류소명         좌표X        좌표Y
# 11100  124900103   25584             길동초등학교  127.146380  37.538756
# 6686   115900078   16812  덕원여자고등학교.덕원예술고등학교  126.832207  37.549261
# 904    102900040    3592            용암경로당입구  126.986992  37.541091
# 3810   110000030   11130           두산힐스빌아파트  127.078930  37.621365
# 8898   120000673   21379         청림동현대아파트입구  126.957231  37.491016
# ...          ...     ...                ...         ...        ...
# 5417   113000121   14212            서강대학교후문  126.944050  37.550476
# 7932   118000276   19367             크라운사거리  126.905338  37.508363
# 7638   117900161   18864            시흥동은행나무  126.909319  37.450794
# 8767   120000126   21228           보라매갑을아파트  126.922020  37.489879
# 7451   117000921   18221              삼익아파트  126.909510  37.462415
#
# [100 rows x 5 columns]

# %%
len(pd.read_csv('서울시버스정류소좌표데이터(2022.08.24).csv', encoding='euc-kr'))
# Out:
# 11167

# %%
# Starting point는 0 부여
loc0_name = '강남역'
loc0_X = '127.028361548'
loc0_Y = '37.496486063'

# %%
# 목적지는 1부터 네이밍;; 목적지 개수는 (num-1) 개

num = 30 # 총 노드 개수

for i in range(1,num): # 1~(n-1)
    globals()[f'loc{i}_name'] = bus_station.iloc[i,2]
    globals()[f'loc{i}_X'] = bus_station.iloc[i,3]
    globals()[f'loc{i}_Y'] = bus_station.iloc[i,4]

# %%
print(loc1_name, loc1_X, loc1_Y)
# Out:
# 덕원여자고등학교.덕원예술고등학교 126.8322065733 37.5492613495

# %%
url = "https://apis.openapi.sk.com/tmap/matrix?version=1"

payload = {
    "origins": [
        {
            "lon": str(globals()[f'loc{i}_X']),
            "lat": str(globals()[f'loc{i}_Y']),
        } for i in range(num)
    ],
    "destinations": [
        {
            "lon": str(globals()[f'loc{i}_X']),
            "lat": str(globals()[f'loc{i}_Y']),
        } for i in range(num)
    ],
    "transportMode": "car",
    "metric": "Recommendation"
}
headers = {
    "Accept": "application/json",
    "appKey": "l7xxcdd1a30a6b34450a881f8083994a8cd4",
    "Content-Type": "application/json"
}

response = requests.post(url, json=payload, headers=headers)

# %%
jsonObj = json.loads(response.text)
jsonObj
# Out:
# {'meta': {'status': 'Ok',
#   'message': 'Ok',
#   'moduleVersion': '',
#   'mapVersion': '20220920',
#   'elapsedTime': 0,
#   'realTimeTrafficDateTime': '',
#   'patternTrafficDate': '',
#   'customizationDateTime': '',
#   'algorithm': '',
#   'metric': 'Recommendation',
#   'requestId': '8263daea-9a9a-4271-b240-14c84f309c64',
#   'gasStationPriceDateTime': '',
#   'transportMode': 'Car',
#   'avoid': []},
#  'origins': [{'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.496486063, 'longitude': 127.028361548},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5492613495, 'longitude': 126.8322065733},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.5410908927, 'longitude': 126.9869921147},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.6213648246, 'longitude': 127.0789297074},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.4910164204, 'longitude': 126.9572310233},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37.6648622202, 'longitude': 127.0598056124},
#    'rpFlag': ''},
#   {'link': {'linkId': '0', 'direction': 'TwoWay'},
#    'poiId': '',
#    'name': '',
#    'coordinate': {'latitude': 37
1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 2797,
#    'distance': 16163.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 3800,
#    'distance': 22878.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 2478,
#    'distance': 20827.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 4825,
#    'distance': 27658.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 1738,
#    'distance': 9226.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 2341,
#    'distance': 11143.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 3365,
#    'distance': 21284.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 794,
#    'distance': 4659.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 2354,
#    'distance': 16841.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 3183,
#    'distance': 15228.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 2815,
#    'distance': 20662.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 20,
#    'cost': 0,
#    'duration': 704,
#    'distance': 3910.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 21,
#    'cost': 0,
#    'duration': 3034,
#    'distance': 20236.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 22,
#    'cost': 0,
#    'duration': 3339,
#    'distance': 21035.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 23,
#    'cost': 0,
#    'duration': 1795,
#    'distance': 9106.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 24,
#    'cost': 0,
#    'duration': 2971,
#    'distance': 19443.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 25,
#    'cost': 0,
#    'duration': 2204,
#    'distance': 10190.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 26,
#    'cost': 0,
#    'duration': 2377,
#    'distance': 18873.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 27,
#    'cost': 0,
#    'duration': 2783,
#    'distance': 14566.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 28,
#    'cost': 0,
#    'duration': 3724,
#    'distance': 22020.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 0,
#    'destinationIndex': 29,
#    'cost': 0,
#    'duration': 1433,
#    'distance': 5190.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 3082,
#    'distance': 25447.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 2500,
#    'distance': 20346.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 4522,
#    'distance': 29799.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 2300,
#    'distance': 18606.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 4289,
#    'distance': 41936.5,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 4524,
#    'distance': 30403.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 1486,
#    'distance': 10202.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 1877,
#    'distance': 13027.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 1369,
#    'distance': 7427.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 4651,
#    'distance': 28129.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 4639,
#    'distance': 43847.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 4985,
#    'distance': 29224.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 4088,
#    'distance': 33582.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 3049,
#    'distance': 20362.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 4387,
#    'distance': 45996.3,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 3756,
#    'distance': 30398.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 3201,
#    'distance': 22034.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 2471,
#    'distance': 13848.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 4693,
#    'distance': 35468.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 20,
#    'cost': 0,
#    'duration': 4029,
#    'distance': 30290.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 21,
#    'cost': 0,
#    'duration': 864,
#    'distance': 4012.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 22,
#    'cost': 0,
#    'duration': 4872,
#    'distance': 31618.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 23,
#    'cost': 0,
#    'duration': 3407,
#    'distance': 25306.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 24,
#    'cost': 0,
#    'duration': 1529,
#    'distance': 10137.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 25,
#    'cost': 0,
#    'duration': 2541,
#    'distance': 17536.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 26,
#    'cost': 0,
#    'duration': 1070,
#    'distance': 5782.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 27,
#    'cost': 0,
#    'duration': 2155,
#    'distance': 15531.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 28,
#    'cost': 0,
#    'duration': 2283,
#    'distance': 12714.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 1,
#    'destinationIndex': 29,
#    'cost': 0,
#    'duration': 2821,
#    'distance': 20385.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 1758,
#    'distance': 8770.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 2846,
#    'distance': 22947.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 2797,
#    'distance': 19650.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 1459,
#    'distance': 9783.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 3712,
#    'distance': 24789.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 2800,
#    'distance': 20254.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 2007,
#    'distance': 16561.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 1673,
#    'distance': 10385.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 2141,
#    'distance': 14305.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 3565,
#    'distance': 23303.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 3210,
#    'distance': 27846.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 3984,
#    'distance': 17798.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 2659,
#    'distance': 17581.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 1817,
#    'distance': 7942.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 3130,
#    'distance': 21709.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 2525,
#    'distance': 12592.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 2360,
#    'distance': 13211.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 2082,
#    'distance': 9486.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 3093,
#    'distance': 19382.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 20,
#    'cost': 0,
#    'duration': 2600,
#    'distance': 14288.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 21,
#    'cost': 0,
#    'duration': 2437,
#    'distance': 20608.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 22,
#    'cost': 0,
#    'duration': 3105,
#    'distance': 21460.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 23,
#    'cost': 0,
#    'duration': 1270,
#    'distance': 5905.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 24,
#    'cost': 0,
#    'duration': 1687,
#    'distance': 15206.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 25,
#    'cost': 0,
#    'duration': 1402,
#    'distance': 4170.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 26,
#    'cost': 0,
#    'duration': 2005,
#    'distance': 18076.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 27,
#    'cost': 0,
#    'duration': 1198,
#    'distance': 4432.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 28,
#    'cost': 0,
#    'duration': 2373,
#    'distance': 9638.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 2,
#    'destinationIndex': 29,
#    'cost': 0,
#    'duration': 1727,
#    'distance': 8967.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 2905,
#    'distance': 23726.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 4219,
#    'distance': 29186.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 2758,
#    'distance': 15810.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 3757,
#    'distance': 25067.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 1137,
#    'distance': 6051.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 359,
#    'distance': 1845.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 3122,
#    'distance': 20138.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 3579,
#    'distance': 28166.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 3568,
#    'distance': 27276.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 1281,
#    'distance': 5386.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 2135,
#    'distance': 16533.1,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 1970,
#    'distance': 9933.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 2117,
#    'distance': 19942.0,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 2168,
#    'distance': 9749.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 677,
#    'distance': 3454.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 3000,
#    'distance': 28064.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 4164,
#    'distance': 39359.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 2503,
#    'distance': 15448.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 1197,
#    'distance': 5448.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 20,
#    'cost': 0,
#    'duration': 2233,
#    'distance': 21052.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 21,
#    'cost': 0,
#    'duration': 3850,
#    'distance': 27823.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 22,
#    'cost': 0,
#    'duration': 618,
#    'distance': 3205.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 23,
#    'cost': 0,
#    'duration': 2157,
#    'distance': 12601.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 24,
#    'cost': 0,
#    'duration': 2995,
#    'distance': 19434.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 25,
#    'cost': 0,
#    'duration': 2535,
#    'distance': 17497.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 26,
#    'cost': 0,
#    'duration': 3346,
#    'distance': 24080.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 27,
#    'cost': 0,
#    'duration': 3333,
#    'distance': 29035.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 28,
#    'cost': 0,
#    'duration': 2754,
#    'distance': 16607.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 3,
#    'destinationIndex': 29,
#    'cost': 0,
#    'duration': 4047,
#    'distance': 24829.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 1638,
#    'distance': 7917.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 2238,
#    'distance': 19392.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 1244,
#    'distance': 7897.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 3261,
#    'distance': 24502.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 4176,
#    'distance': 29641.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 3263,
#    'distance': 25106.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 1941,
#    'distance': 15464.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 1195,
#    'distance': 5716.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 1870,
#    'distance': 8865.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 4029,
#    'distance': 28155.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 3488,
#    'distance': 27839.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 5054,
#    'distance': 32934.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 2516,
#    'distance': 22328.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 2660,
#    'distance': 13866.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 3594,
#    'distance': 26561.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 1588,
#    'distance': 14276.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 972,
#    'distance': 3567.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 2321,
#    'distance': 16158.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 3557,
#    'distance': 24234.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 20,
#    'cost': 0,
#    'duration': 2077,
#    'distance': 17425.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 21,
#    'cost': 0,
#    'duration': 2054,
#    'distance': 15884.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 22,
#    'cost': 0,
#    'duration': 3569,
#    'distance': 26311.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 23,
#    'cost': 0,
#    'duration': 1952,
#    'distance': 11813.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 24,
#    'cost': 0,
#    'duration': 1621,
#    'distance': 14109.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 25,
#    'cost': 0,
#    'duration': 2002,
#    'distance': 10116.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 26,
#    'cost': 0,
#    'duration': 1397,
#    'distance': 14521.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 27,
#    'cost': 0,
#    'duration': 1434,
#    'distance': 9232.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 28,
#    'cost': 0,
#    'duration': 2374,
#    'distance': 16687.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 4,
#    'destinationIndex': 29,
#    'cost': 0,
#    'duration': 568,
#    'distance': 2419.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 3574,
#    'distance': 28368.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 4378,
#    'distance': 46414.1,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 3577,
#    'distance': 20452.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 1177,
#    'distance': 6229.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 4425,
#    'distance': 29710.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 1362,
#    'distance': 6856.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 3941,
#    'distance': 24779.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 4397,
#    'distance': 32807.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 4387,
#    'distance': 31918.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 1071,
#    'distance': 5097.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 2411,
#    'distance': 27475.8,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 1337,
#    'distance': 4873.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 2852,
#    'distance': 24274.5,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 2548,
#    'distance': 12331.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 1037,
#    'distance': 4545.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 3669,
#    'distance': 32706.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 4833,
#    'distance': 44002.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 3322,
#    'distance': 20089.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 1933,
#    'distance': 9781.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 20,
#    'cost': 0,
#    'duration': 2902,
#    'distance': 25695.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 21,
#    'cost': 0,
#    'duration': 4669,
#    'distance': 32465.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 22,
#    'cost': 0,
#    'duration': 925,
#    'distance': 3708.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 23,
#    'cost': 0,
#    'duration': 2975,
#    'distance': 17242.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 24,
#    'cost': 0,
#    'duration': 3813,
#    'distance': 24076.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 25,
#    'cost': 0,
#    'duration': 3420,
#    'distance': 16025.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 26,
#    'cost': 0,
#    'duration': 4165,
#    'distance': 28721.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 27,
#    'cost': 0,
#    'duration': 4152,
#    'distance': 33677.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 28,
#    'cost': 0,
#    'duration': 3573,
#    'distance': 21249.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 5,
#    'destinationIndex': 29,
#    'cost': 0,
#    'duration': 4716,
#    'distance': 29472.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 2928,
#    'distance': 21800.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 4411,
#    'distance': 29811.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 2654,
#    'distance': 13525.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 500,
#    'distance': 1846.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 3780,
#    'distance': 23141.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 1346,
#    'distance': 6856.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 3314,
#    'distance': 20763.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 3771,
#    'distance': 28791.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 3760,
#    'distance': 27902.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 1472,
#    'distance': 6012.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 2285,
#    'distance': 17447.1,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 2179,
#    'distance': 10738.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 2267,
#    'distance': 20856.0,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 1949,
#    'distance': 9578.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 885,
#    'distance': 4259.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 3023,
#    'distance': 26138.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 4188,
#    'distance': 37433.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 2695,
#    'distance': 16073.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 1054,
#    'distance': 4098.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 20,
#    'cost': 0,
#    'duration': 2256,
#    'distance': 19127.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 21,
#    'cost': 0,
#    'duration': 4042,
#    'distance': 28449.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 22,
#    'cost': 0,
#    'duration': 827,
#    'distance': 4009.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 23,
#    'cost': 0,
#    'duration': 2188,
#    'distance': 9748.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 24,
#    'cost': 0,
#    'duration': 3186,
#    'distance': 20060.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 25,
#    'cost': 0,
#    'duration': 2859,
#    'distance': 12509.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 26,
#    'cost': 0,
#    'duration': 3538,
#    'distance': 24705.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 27,
#    'cost': 0,
#    'duration': 3525,
#    'distance': 29661.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 28,
#    'cost': 0,
#    'duration': 2946,
#    'distance': 17233.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 6,
#    'destinationIndex': 29,
#    'cost': 0,
#    'duration': 4071,
#    'distance': 22903.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 2487,
#    'distance': 20588.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 1758,
#    'distance': 9478.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 1766,
#    'distance': 11279.8,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 2928,
#    'distance': 20000.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 1917,
#    'distance': 15391.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 3886,
#    'distance': 25148.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 2931,
#    'distance': 20604.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 1522,
#    'distance': 10206.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 1509,
#    'distance': 9453.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 3057,
#    'distance': 18330.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 4053,
#    'distance': 33238.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 3391,
#    'distance': 19424.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 3304,
#    'distance': 28679.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 1860,
#    'distance': 11350.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 3304,
#    'distance': 22068.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 3272,
#    'distance': 25601.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 2818,
#    'distance': 18819.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 867,
#    'distance': 4299.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 3461,
#    'distance': 23182.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 20,
#    'cost': 0,
#    'duration': 2984,
#    'distance': 23804.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 21,
#    'cost': 0,
#    'duration': 1582,
#    'distance': 10068.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 22,
#    'cost': 0,
#    'duration': 3279,
#    'distance': 21818.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 23,
#    'cost': 0,
#    'duration': 2168,
#    'distance': 12352.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 24,
#    'cost': 0,
#    'duration': 429,
#    'distance': 1125.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 25,
#    'cost': 0,
#    'duration': 1351,
#    'distance': 8524.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 26,
#    'cost': 0,
#    'duration': 1078,
#    'distance': 6325.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 27,
#    'cost': 0,
#    'duration': 1555,
#    'distance': 11328.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 28,
#    'cost': 0,
#    'duration': 678,
#    'distance': 3165.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 7,
#    'destinationIndex': 29,
#    'cost': 0,
#    'duration': 2330,
#    'distance': 18735.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 2083,
#    'distance': 14404.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 1833,
#    'distance': 13039.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 1412,
#    'distance': 9273.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 3356,
#    'distance': 26565.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 1126,
#    'distance': 6016.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 4271,
#    'distance': 31704.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 3359,
#    'distance': 27169.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 1408,
#    'distance': 9930.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 732,
#    'distance': 3589.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 4124,
#    'distance': 30218.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 3640,
#    'distance': 32804.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 4501,
#    'distance': 28704.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 3089,
#    'distance': 22539.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 2334,
#    'distance': 14842.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 3689,
#    'distance': 28624.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 2757,
#    'distance': 19355.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 8,
# ...
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 26,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 3715,
#    'distance': 23256.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 26,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 3766,
#    'distance': 38428.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 26,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 4049,
#    'distance': 24350.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 26,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 3216,
#    'distance': 28163.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 26,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 2201,
#    'distance': 15752.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 26,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 3962,
#    'distance': 26994.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 26,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 2884,
#    'distance': 24979.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 26,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 2329,
#    'distance': 16614.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 26,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 1623,
#    'distance': 9238.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 26,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 3845,
#    'distance': 30858.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 26,
#    'destinationIndex': 20,
#    'cost': 0,
#    'duration': 3156,
#    'distance': 24870.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 26,
#    'destinationIndex': 21,
#    'cost': 0,
#    'duration': 962,
#    'distance': 4637.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 26,
#    'destinationIndex': 22,
#    'cost': 0,
#    'duration': 3937,
#    'distance': 26745.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 26,
#    'destinationIndex': 23,
#    'cost': 0,
#    'duration': 2559,
#    'distance': 20696.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 26,
#    'destinationIndex': 24,
#    'cost': 0,
#    'duration': 681,
#    'distance': 5527.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 26,
#    'destinationIndex': 25,
#    'cost': 0,
#    'duration': 1693,
#    'distance': 12926.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 26,
#    'destinationIndex': 26,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 26,
#    'destinationIndex': 27,
#    'cost': 0,
#    'duration': 1307,
#    'distance': 10921.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 26,
#    'destinationIndex': 28,
#    'cost': 0,
#    'duration': 1435,
#    'distance': 8104.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 26,
#    'destinationIndex': 29,
#    'cost': 0,
#    'duration': 1949,
#    'distance': 14966.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 2350,
#    'distance': 12774.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 2267,
#    'distance': 16665.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 979,
#    'distance': 4146.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 3660,
#    'distance': 23719.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 1507,
#    'distance': 7577.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 4575,
#    'distance': 28858.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 3663,
#    'distance': 24323.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 1612,
#    'distance': 11612.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 1480,
#    'distance': 8170.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 1742,
#    'distance': 9487.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 3547,
#    'distance': 18604.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 3917,
#    'distance': 25423.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 4036,
#    'distance': 23193.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 3167,
#    'distance': 20864.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 1940,
#    'distance': 10870.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 3993,
#    'distance': 25778.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 3189,
#    'distance': 15251.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 2408,
#    'distance': 11005.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 1595,
#    'distance': 8605.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 3956,
#    'distance': 23450.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 20,
#    'cost': 0,
#    'duration': 2847,
#    'distance': 15989.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 21,
#    'cost': 0,
#    'duration': 2042,
#    'distance': 15659.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 22,
#    'cost': 0,
#    'duration': 3968,
#    'distance': 25528.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 23,
#    'cost': 0,
#    'duration': 1559,
#    'distance': 7644.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 24,
#    'cost': 0,
#    'duration': 1292,
#    'distance': 10257.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 25,
#    'cost': 0,
#    'duration': 1339,
#    'distance': 6308.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 26,
#    'cost': 0,
#    'duration': 1534,
#    'distance': 11401.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 27,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 28,
#    'cost': 0,
#    'duration': 1500,
#    'distance': 8013.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 27,
#    'destinationIndex': 29,
#    'cost': 0,
#    'duration': 2028,
#    'distance': 9356.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 2742,
#    'distance': 21794.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 2333,
#    'distance': 11760.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 1410,
#    'distance': 9091.6,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 2506,
#    'distance': 16959.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 2172,
#    'distance': 16597.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 3464,
#    'distance': 22107.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 2508,
#    'distance': 17563.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 682,
#    'distance': 3165.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 1777,
#    'distance': 11412.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 1763,
#    'distance': 10659.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 2635,
#    'distance': 15289.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 3976,
#    'distance': 31226.5,
#    'toll': True},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 2968,
#    'distance': 16383.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 3256,
#    'distance': 30248.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 1483,
#    'distance': 8550.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 2882,
#    'distance': 19027.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 3527,
#    'distance': 26807.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 3073,
#    'distance': 20025.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 243,
#    'distance': 1205.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 3038,
#    'distance': 20142.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 20,
#    'cost': 0,
#    'duration': 3060,
#    'distance': 27792.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 21,
#    'cost': 0,
#    'duration': 1836,
#    'distance': 11274.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 22,
#    'cost': 0,
#    'duration': 2856,
#    'distance': 18778.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 23,
#    'cost': 0,
#    'duration': 1792,
#    'distance': 9552.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 24,
#    'cost': 0,
#    'duration': 645,
#    'distance': 2813.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 25,
#    'cost': 0,
#    'duration': 975,
#    'distance': 5724.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 26,
#    'cost': 0,
#    'duration': 1332,
#    'distance': 7531.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 27,
#    'cost': 0,
#    'duration': 1313,
#    'distance': 7523.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 28,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 28,
#    'destinationIndex': 29,
#    'cost': 0,
#    'duration': 2584,
#    'distance': 19941.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 0,
#    'cost': 0,
#    'duration': 1263,
#    'distance': 5541.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 1,
#    'cost': 0,
#    'duration': 2749,
#    'distance': 20582.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 2,
#    'cost': 0,
#    'duration': 1301,
#    'distance': 7898.3,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 3,
#    'cost': 0,
#    'duration': 3169,
#    'distance': 22667.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 4,
#    'cost': 0,
#    'duration': 618,
#    'distance': 3131.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 5,
#    'cost': 0,
#    'duration': 4084,
#    'distance': 27806.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 6,
#    'cost': 0,
#    'duration': 3172,
#    'distance': 23271.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 7,
#    'cost': 0,
#    'duration': 2375,
#    'distance': 17731.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 8,
#    'cost': 0,
#    'duration': 1573,
#    'distance': 7489.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 9,
#    'cost': 0,
#    'duration': 2283,
#    'distance': 14374.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 10,
#    'cost': 0,
#    'duration': 3937,
#    'distance': 26320.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 11,
#    'cost': 0,
#    'duration': 3407,
#    'distance': 30963.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 12,
#    'cost': 0,
#    'duration': 4963,
#    'distance': 31099.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 13,
#    'cost': 0,
#    'duration': 2485,
#    'distance': 18484.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 14,
#    'cost': 0,
#    'duration': 2725,
#    'distance': 14273.9,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 15,
#    'cost': 0,
#    'duration': 3502,
#    'distance': 24726.7,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 16,
#    'cost': 0,
#    'duration': 1556,
#    'distance': 10431.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 17,
#    'cost': 0,
#    'duration': 1664,
#    'distance': 7347.4,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 18,
#    'cost': 0,
#    'duration': 2873,
#    'distance': 19233.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 19,
#    'cost': 0,
#    'duration': 3465,
#    'distance': 22399.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 20,
#    'cost': 0,
#    'duration': 1789,
#    'distance': 8803.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 21,
#    'cost': 0,
#    'duration': 2564,
#    'distance': 17074.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 22,
#    'cost': 0,
#    'duration': 3477,
#    'distance': 24477.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 23,
#    'cost': 0,
#    'duration': 2179,
#    'distance': 12237.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 24,
#    'cost': 0,
#    'duration': 2201,
#    'distance': 16951.2,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 25,
#    'cost': 0,
#    'duration': 2453,
#    'distance': 12068.8,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 26,
#    'cost': 0,
#    'duration': 1907,
#    'distance': 15711.5,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 27,
#    'cost': 0,
#    'duration': 1812,
#    'distance': 11006.1,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 28,
#    'cost': 0,
#    'duration': 2954,
#    'distance': 19528.6,
#    'toll': False},
#   {'status': 'Ok',
#    'originIndex': 29,
#    'destinationIndex': 29,
#    'cost': 0,
#    'duration': 0,
#    'distance': 0.0,
#    'toll': False}]}

# %%
jsonObj['matrixRoutes'][0]
# Out:
# {'status': 'Ok',
#  'originIndex': 0,
#  'destinationIndex': 0,
#  'cost': 0,
#  'duration': 0,
#  'distance': 0.0,
#  'toll': False}

# %%
duration_lst = []
distance_lst = []
for i in range(num**2):
    duration_lst.append(jsonObj['matrixRoutes'][i]['duration'])
    distance_lst.append(jsonObj['matrixRoutes'][i]['distance'])
duration = np.array(duration_lst).reshape(num,num)
distance = np.array(distance_lst).reshape(num,num)

# %%
print(duration.shape)
duration
# Out:
# (30, 30)
# array([[   0, 3219, 1426, 3031, 2026, 3946, 3034, 3291, 2401, 2797, 3800,
#         2478, 4825, 1738, 2341, 3365,  794, 2354, 3183, 2815,  704, 3034,
#         3339, 1795, 2971, 2204, 2377, 2783, 3724, 1433],
#        [3082,    0, 2500, 4522, 2300, 4289, 4524, 1486, 1877, 1369, 4651,
#         3766, 4049, 3216, 2201, 3962, 2884, 2329, 1623, 3845, 3156,  962,
#         3937, 2559,  681, 1693,    0, 1307, 1435, 1949],
#        [2350, 2267,  979, 3660, 1507, 4575, 3663, 1612, 1480, 1742, 3547,
#         3917, 4036, 3167, 1940, 3993, 3189, 2408, 1595, 3956, 2847, 2042,
#         3968, 1559, 1292, 1339, 1534,    0, 1500, 2028],
#        [2742, 2333, 1410, 2506, 2172, 3464, 2508,  682, 1777, 1763, 2635,
#         3976, 2968, 3256, 1483, 2882, 3527, 3073,  243, 3038, 3060, 1836,
#         2856, 1792,  645,  975, 1332, 1313,    0, 2584],
#        [1263, 2749, 1301, 3169,  618, 4084, 3172, 2375, 1573, 2283, 3937,
#         3407, 4963, 2485, 2725, 3502, 1556, 1664, 2873, 3465, 1789, 2564,
#         3477, 2179, 2201, 2453, 1907, 1812, 2954,    0]])

# %%
print(distance.shape)
distance
# Out:
# (30, 30)
# array([[    0. , 23744.7,  7916. , 19225.6,  8278.3, 24364.9, 19829.6,
#         20798. , 12042.1, 16163.8, 22878.7, 20827.6, 27658. ,  9226.8,
#         11143.4, 21284.8,  4659.5, 16841.5, 15228.1, 20662.9,  3910.1,
#         20236.4, 21035.2,  9106.6, 19443.2, 10190. , 18873.4, 14566. ,
#         22020.6,  5190.5],
#        [25447.6,     0. , 20346.6, 29799.9, 18606.2, 41936.5, 30403.9,
#         10202.3, 13027.1,  7427.4, 28129.6, 43847.5, 29224. , 33582.9,
#         20362.6, 45996.3, 30398.9, 22034.2, 13848.3, 35468.2, 30290. ,
#          4012.5, 31618.4, 25306.1, 10137.3, 17536.5,  5782.5, 15531.1,
#         12714.7, 20385.6],
#        [ 8770.9, 22947.4,     0. , 19650.6,  9783.8, 24789.9, 20254.6,
#         16561. , 10385.2, 14305.6, 23303.7, 27846.1, 17798.1, 17581.5,
#          7942.4, 21709.8, 12592.6, 13211.8,  9486.9, 19382.3, 14288.6,
#         20608.1, 21460.2,  5905.6, 15206.2,  4170.4, 18076.1,  4432.4,
#          9638.8,  8967.2],
#        [23726.1, 29186.1, 15810.4,     0. , 25067.5,  6051.9,  1845. ,
#         20138. , 28166. , 27276.5,  5386.7, 16533.1,  9933.5, 19942. ,
#          9749.8,  3454.9, 28064. , 39359.3, 15448. ,  5448.7, 21052.8,
#         27823.7,  3205.3, 12601.2, 19434.6, 17497.9, 24080. , 29035.8,
#         16607.5, 24829.5],
#        [ 7917.3, 19392.4,  7897.3, 24502.3,     0. , 29641.6, 25106.3,
#         15464.6,  5716.2,  8865.3, 28155.4, 27839.3, 32934.7, 22328.9,
#         13866.6, 26561.5, 14276.2,  3567. , 16158.6, 24234. , 17425.9,
#         15884.1, 26311.9, 11813.1, 14109.8, 10116.5, 14521.1,  9232.6,
#         16687.2,  2419.4],
#        [28368.9, 46414.1, 20452.1,  6229.2, 29710.3,     0. ,  6856.5,
#         24779.7, 32807.7, 31918.2,  5097.8, 27475.8,  4873.1, 24274.5,
#         12331.2,  4545.8, 32706.8, 44002.1, 20089.7,  9781.2, 25695.6,
#        [25403.3, 31296.3, 17920.6,  3356.1, 26744.7,  3708.2,  3960.1,
#         22248.2, 30276.2, 29386.7,  3508.4, 18957.2,  7154.2, 22366.1,
#          8600.9,  1040.8, 29741.2, 41036.5, 17558.2,  7872.8, 22730. ,
#         29933.9,     0. , 14711.4, 21544.8, 12294.8, 26190.2, 31146. ,
#         18717.7, 26506.7],
#        [ 9420. , 26805.2,  4744.1, 15924.8, 12772.7, 21064.1, 16528.8,
#         12475.4, 12888.5, 14204.9, 10206.3, 19229.5, 12080.7, 14670.4,
#          3424.4,  9839.4, 11566.7, 23182. ,  9505.2, 15656.5, 10116.9,
#         20079.8, 17734.4,     0. , 12462.2,  4080.2, 21933.9,  6658.2,
#         12127.4, 13289.4],
#        [19242.4,  9207.7, 10416.2, 19673.9, 14044.7, 24822.1, 20277.9,
#          1125.2,  8860.1,  8107.3, 18003.6, 31892.2, 19098. , 27333.1,
#         10486.9, 21742. , 24254.8, 17472.7,  3948.4, 22856.4, 22457.9,
#          8722.4, 21492.4, 11488.5,     0. ,  7660.8,  4978.7,  9982.1,
#          2814.8, 17389.3],
#        [17518.5, 16265. ,  5808. , 19846.3, 10584.1, 16234.9, 20450.3,
#          8175.3,  9444.9, 10761.3, 12387.9, 30168.3, 14262.3, 25609.2,
#          4653.1, 12021. , 17754.6, 14012.1,  5122.1, 13968.9, 15348.7,
#         15779.7, 12905.2,  5654.7,  8162.1,     0. , 12036. ,  4240. ,
#          5274. , 12363.5],
#        [20028.2,  4900.1, 14927.2, 24926.5, 13186.8, 39868. , 25530.5,
#          6882.2,  7607.7,  5973.8, 23256.2, 38428.1, 24350.6, 28163.5,
#         15752.7, 26994.6, 24979.5, 16614.8,  9238.4, 30858.3, 24870.6,
#          4637. , 26745. , 20696.2,  5527.4, 12926.6,     0. , 10921.2,
#          8104.8, 14966.2],
#        [12774. , 16665.4,  4146.1, 23719.1,  7577.2, 28858.4, 24323.1,
#         11612.2,  8170.8,  9487.2, 18604.9, 25423.8, 23193.2, 20864.7,
#         10870.1, 25778.3, 15251.3, 11005.2,  8605. , 23450.8, 15989.5,
#         15659.3, 25528.7,  7644. , 10257.4,  6308.5, 11401.4,     0. ,
#          8013.7,  9356.6],
#        [21794.7, 11760. ,  9091.6, 16959.6, 16597. , 22107.8, 17563.6,
#          3165.4, 11412.4, 10659.6, 15289.3, 31226.5, 16383.7, 30248.2,
#          8550.7, 19027.7, 26807.1, 20025. ,  1205.4, 20142.1, 27792.8,
#         11274.7, 18778.1,  9552.3,  2813.9,  5724.6,  7531. ,  7523.6,
#             0. , 19941.6],
#        [ 5541.5, 20582.8,  7898.3, 22667.5,  3131.4, 27806.8, 23271.5,
#         17731.8,  7489.7, 14374.5, 26320.6, 30963.4, 31099.9, 18484.5,
#         14273.9, 24726.7, 10431.8,  7347.4, 19233.1, 22399.2,  8803.2,
#         17074.5, 24477.1, 12237.1, 16951.2, 12068.8, 15711.5, 11006.1,
#         19528.6,     0. ]])

# %%
np.save('강남역_경로매트릭스(분)',duration)

# %%
np.save('강남역_경로매트릭(미터)',distance)
